# %% [markdown]
# # Reading & Writing csv files As DataFrame (Pandas)

# %%
#Reading & writing - Using pandas
import pandas as pd

# %%
df = pd.read_csv('tv_shows.csv')

# %%
df
# Out:
#       Unnamed: 0    ID                                  Title  Year  Age  \
# 0              0     1                           Breaking Bad  2008  18+
# 1              1     2                        Stranger Things  2016  16+
# 2              2     3                        Attack on Titan  2013  18+
# 3              3     4                       Better Call Saul  2015  18+
# 4              4     5                                   Dark  2017  16+
# ...          ...   ...                                    ...   ...  ...
# 5363        5363  5713                       Paradise Islands  2017  NaN
# 5364        5364  5714                         Mexico Untamed  2018  NaN
# 5365        5365  5715                  Wild Centeral America  2020  NaN
# 5366        5366  5716                            Wild Russia  2018  NaN
# 5367        5367  5717  Fearless Adventures with Jack Randall  2018  NaN
#
#         IMDb Rotten Tomatoes Netflix  Hulu  Prime Video  Disney+  Type  \
# ...

# %%
type(df) # It is a dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
# write
df.to_csv('C:/Users/Laxman/Downloads/sample.csv')

# %%
df1 = pd.read_csv('C:/Users/Laxman/Downloads/data.csv')

# %%
# write
df1.to_csv('C:/Users/Laxman/Downloads/data.csv')

# %%
df1
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
# for changing to a directory, import library "Operating Systems" i.e., import os
import os

# %%
os.chdir('C:/Users/Laxman/Downloads')

# %%
# !dir (! is a OS command)
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is E48E-6850
#
#  Directory of C:\Users\Laxman\Downloads
#
#
#  Directory of C:\Users\Laxman\Downloads
#
#
#  Directory of C:\Users\Laxman\Downloads
#
#
#  Directory of C:\Users\Laxman\Downloads
#
#
#  Directory of C:\Users\Laxman\Downloads
# File Not Found

# %%
# !type data.csv
# Out:
# ,Duration,Pulse,Maxpulse,Calories
# 0,60,110,130,409.1
# 1,60,117,145,479.0
# 2,60,103,135,340.0
# 3,45,109,175,282.4
# 4,45,117,148,406.0
# 5,60,102,127,300.0
# 6,60,110,136,374.0
# 7,45,104,134,253.3
# 8,30,109,133,195.1
# 9,60,98,124,269.0
# 10,60,103,147,329.3
# 11,60,100,120,250.7
# 12,60,106,128,345.3
# 13,60,104,132,379.3
# 14,60,98,123,275.0
# 15,60,98,120,215.2
# 16,60,100,120,300.0
# 17,45,90,112,
# 18,60,103,123,323.0
# 19,45,97,125,243.0
# 20,60,108,131,364.2
# 21,45,100,119,282.0
# 22,60,130,101,300.0
# 23,45,105,132,246.0
# 24,60,102,126,334.5
# 25,60,100,120,250.0
# 26,60,92,118,241.0
# 27,60,103,132,
# 28,60,100,132,280.0
# 29,60,102,129,380.3
# 30,60,92,115,243.0
# 31,45,90,112,180.1
# 32,60,101,124,299.0
# 33,60,93,113,223.0
# 34,60,107,136,361.0
# 35,60,114,140,415.0
# 36,60,102,127,300.0
# 37,60,100,120,300.0
# 38,60,100,120,300.0
# 39,45,104,129,266.0
# 40,45,90,112,180.1
# 41,60,98,126,286.0
# 42,60,100,122,329.4
# 43,60,111,138,400.0
# 44,60,111,131,397.0
# ...

# %%
df1 = pd.read_csv('data.csv')
df1
# Out:
#      Unnamed: 0  Duration  Pulse  Maxpulse  Calories
# 0             0        60    110       130     409.1
# 1             1        60    117       145     479.0
# 2             2        60    103       135     340.0
# 3             3        45    109       175     282.4
# 4             4        45    117       148     406.0
# ..          ...       ...    ...       ...       ...
# 164         164        60    105       140     290.8
# 165         165        60    110       145     300.0
# 166         166        60    115       145     310.2
# 167         167        75    120       150     320.4
# 168         168        75    125       150     330.4
#
# [169 rows x 5 columns]

# %%
df2 = pd.read_csv("data.csv", header=None)
df2
# Out:
#          0         1      2         3         4
# 0      NaN  Duration  Pulse  Maxpulse  Calories
# 1      0.0        60    110       130     409.1
# 2      1.0        60    117       145     479.0
# 3      2.0        60    103       135     340.0
# 4      3.0        45    109       175     282.4
# ..     ...       ...    ...       ...       ...
# 165  164.0        60    105       140     290.8
# 166  165.0        60    110       145     300.0
# 167  166.0        60    115       145     310.2
# 168  167.0        75    120       150     320.4
# 169  168.0        75    125       150     330.4
#
# [170 rows x 5 columns]

# %%
#If you wish to change headings of columns
df3 = pd.read_csv("data.csv", names=['BR','Sqft', 'Locality','Price'])
df3
# Out:
#              BR   Sqft  Locality     Price
# NaN    Duration  Pulse  Maxpulse  Calories
# 0.0          60    110       130     409.1
# 1.0          60    117       145     479.0
# 2.0          60    103       135     340.0
# 3.0          45    109       175     282.4
# ...         ...    ...       ...       ...
# 164.0        60    105       140     290.8
# 165.0        60    110       145     300.0
# 166.0        60    115       145     310.2
# 167.0        75    120       150     320.4
# 168.0        75    125       150     330.4
#
# [170 rows x 4 columns]

# %%
df4 = pd.read_csv('data.csv')
df4
# Out:
#      Unnamed: 0  Duration  Pulse  Maxpulse  Calories
# 0             0        60    110       130     409.1
# 1             1        60    117       145     479.0
# 2             2        60    103       135     340.0
# 3             3        45    109       175     282.4
# 4             4        45    117       148     406.0
# ..          ...       ...    ...       ...       ...
# 164         164        60    105       140     290.8
# 165         165        60    110       145     300.0
# 166         166        60    115       145     310.2
# 167         167        75    120       150     320.4
# 168         168        75    125       150     330.4
#
# [169 rows x 5 columns]

# %%
#If you wish to remove the redundant column1
df5 = pd.read_csv("data.csv", usecols=range(1,5))
df5
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df6 = pd.read_csv('data.csv',usecols=range(1,5), skiprows=1)
df6
# Out:
#      60  110  130  409.1
# 0    60  117  145  479.0
# 1    60  103  135  340.0
# 2    45  109  175  282.4
# 3    45  117  148  406.0
# 4    60  102  127  300.0
# ..   ..  ...  ...    ...
# 163  60  105  140  290.8
# 164  60  110  145  300.0
# 165  60  115  145  310.2
# 166  75  120  150  320.4
# 167  75  125  150  330.4
#
# [168 rows x 4 columns]

# %%
#read only first 3
df7 = pd.read_csv('data.csv', nrows=3)
df7
# Out:
#    Unnamed: 0  Duration  Pulse  Maxpulse  Calories
# 0           0        60    110       130     409.1
# 1           1        60    117       145     479.0
# 2           2        60    103       135     340.0
